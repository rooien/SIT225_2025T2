# %%
import serial
import time
import random
from datetime import datetime

# Connect to Arduino on COM9 at 9600 baud rate
# 'timeout=5' means it will wait up to 5 seconds for a response
arduino = serial.Serial('COM9', 9600, timeout=5)
time.sleep(2)  # Give Arduino 2 seconds to reset after connecting

# Logging function with timestamp
def log(msg):
    print(f"[{datetime.now().strftime('%H:%M:%S')}] {msg}")

# Infinite loop to communicate continuously
while True:
    # Step 1: Generate a random number between 1 and 5
    blink_count = random.randint(1, 5)

    # Step 2: Send the number to Arduino as a string with newline
    arduino.write(f"{blink_count}\n".encode())  # .encode() converts string to bytes
    log(f"Sent: {blink_count} blinks")

    # Step 3: Wait for Arduino to send a response (how many seconds to wait)
    response = arduino.readline().decode().strip()  # Read and decode serial response

    # Step 4: If the response is a valid number, sleep for that many seconds
    if response.isdigit():
        wait_time = int(response)
        log(f"Arduino said: wait {wait_time} seconds")
        log(f"Sleeping...")
        time.sleep(wait_time)  # Wait before sending the next blink command
        log("Done.\n")
    else:
        log("No valid response from Arduino.")
# Out:
# [18:25:47] Sent: 4 blinks
# [18:25:51] Arduino said: wait 1 seconds
# [18:25:51] Sleeping...
# [18:25:52] Done.
#
# [18:25:52] Sent: 2 blinks
# [18:25:52] Arduino said: wait 2 seconds
# [18:25:52] Sleeping...
# [18:25:54] Done.
#
# [18:25:54] Sent: 1 blinks
# [18:25:54] Arduino said: wait 5 seconds
# [18:25:54] Sleeping...
# [18:25:59] Done.
#
# [18:25:59] Sent: 4 blinks
# [18:25:59] Arduino said: wait 4 seconds
# [18:25:59] Sleeping...
# [18:26:03] Done.
#
# [18:26:03] Sent: 2 blinks
# [18:26:03] Arduino said: wait 2 seconds
# [18:26:03] Sleeping...
# [18:26:05] Done.
#
# [18:26:05] Sent: 3 blinks
# [18:26:05] Arduino said: wait 1 seconds
# [18:26:05] Sleeping...
# [18:26:06] Done.
#
# [18:26:06] Sent: 5 blinks
# [18:26:06] Arduino said: wait 2 seconds
# [18:26:06] Sleeping...
# [18:26:08] Done.
#
# [18:26:08] Sent: 4 blinks
# [18:26:08] Arduino said: wait 5 seconds
# [18:26:08] Sleeping...
# [18:26:13] Done.
#
# [18:26:13] Sent: 2 blinks
# [18:26:13] Arduino said: wait 3 seconds
# [18:26:13] Sleeping...
# [18:26:16] Done.
#
# [18:26:16] Sent: 4 blinks
# [18:26:17] Arduino said: wait 2 seconds
# [18:26:17] Sleeping...
# [18:26:19] Done.
#
# [18:26:19] Sent: 3 blinks
# [18:26:19] Arduino said: wait 5 seconds
# [18:26:19] Sleeping...
# [18:26:24] Done.
#
# [18:26:24] Sent: 2 blinks
# [18:26:24] Arduino said: wait 3 seconds
# [18:26:24] Sleeping...
# [18:26:27] Done.
#
# [18:26:27] Sent: 5 blinks
# [18:26:27] Arduino said: wait 5 seconds
# [18:26:27] Sleeping...
# [18:26:32] Done.
#
# [18:26:32] Sent: 1 blinks
# [18:26:32] Arduino said: wait 1 seconds
# [18:26:32] Sleeping...
# [18:26:33] Done.
#
# [18:26:33] Sent: 2 blinks
# [18:26:33] Arduino said: wait 2 seconds
# [18:26:33] Sleeping...
# [18:26:35] Done.
#
# [18:26:35] Sent: 3 blinks
# [18:26:35] Arduino said: wait 4 seconds
# [18:26:35] Sleeping...
# [18:26:39] Done.
#
# [18:26:39] Sent: 4 blinks
# [18:26:39] Arduino said: wait 4 seconds
# [18:26:39] Sleeping...
# [18:26:43] Done.
#
# [18:26:43] Sent: 3 blinks
# [18:26:43] Arduino said: wait 4 seconds
# [18:26:43] Sleeping...
# [18:26:47] Done.
#
# [18:26:47] Sent: 1 blinks
# [18:26:47] Arduino said: wait 4 seconds
# [18:26:47] Sleeping...
# [18:26:51] Done.
#
# [18:26:51] Sent: 2 blinks
# [18:26:51] Arduino said: wait 3 seconds
# [18:26:51] Sleeping...
# [18:26:54] Done.
#
# [18:26:54] Sent: 1 blinks
# [18:26:54] Arduino said: wait 2 seconds
# [18:26:54] Sleeping...
# [18:26:56] Done.
#
# [18:26:56] Sent: 3 blinks
# [18:26:56] Arduino said: wait 3 seconds
# [18:26:56] Sleeping...
# [18:26:59] Done.
#
# [18:26:59] Sent: 3 blinks
# [18:26:59] Arduino said: wait 2 seconds
# [18:26:59] Sleeping...
# [18:27:01] Done.
#
# [18:27:01] Sent: 1 blinks
# [18:27:01] Arduino said: wait 2 seconds
# [18:27:01] Sleeping...
# [18:27:03] Done.
#
# [18:27:03] Sent: 2 blinks
# [18:27:03] Arduino said: wait 3 seconds
# [18:27:03] Sleeping...
# [18:27:06] Done.
#
# [18:27:06] Sent: 1 blinks
# [18:27:06] Arduino said: wait 4 seconds
# [18:27:06] Sleeping...
# [18:27:10] Done.
#
# [18:27:10] Sent: 5 blinks
# [18:27:10] Arduino said: wait 1 seconds
# [18:27:10] Sleeping...
# [18:27:11] Done.
#
# [18:27:11] Sent: 3 blinks
# [18:27:11] Arduino said: wait 4 seconds
# [18:27:11] Sleeping...
# [18:27:15] Done.
#
# [18:27:15] Sent: 4 blinks
# [18:27:15] Arduino said: wait 2 seconds
# [18:27:15] Sleeping...
# [18:27:17] Done.
#
# [18:27:17] Sent: 1 blinks
# [18:27:17] Arduino said: wait 5 seconds
# [18:27:17] Sleeping...
# [18:27:22] Done.
#
# [18:27:22] Sent: 5 blinks
# [18:27:22] Arduino said: wait 3 seconds
# [18:27:22] Sleeping...
# [18:27:25] Done.
#
# [18:27:25] Sent: 1 blinks
# [18:27:25] Arduino said: wait 3 seconds
# [18:27:25] Sleeping...
# [18:27:28] Done.
#
# [18:27:28] Sent: 1 blinks
# [18:27:28] Arduino said: wait 4 seconds
# [18:27:28] Sleeping...
